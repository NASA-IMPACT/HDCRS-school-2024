# %%
# !pip install transformers bitsandbytes accelerate boto3
# !pip install boto3 bitsandbytes accelerate

BUCKET_NAME = 'workhsop-llama-weights'
LORA_FILENAME = 'lora_tensors.safetensors'
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (1.34.51)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.10/site-packages (0.43.1)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.30.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.51 in /opt/conda/lib/python3.10/site-packages (from boto3) (1.34.51)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3) (0.10.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (2.0.0.post104)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.23.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.51->boto3) (2.9.0)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.51->boto3) (1.26.18)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.14.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.51->boto3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)

# %%
import boto3
import os
def assumed_role_session():
    # Assume the "notebookAccessRole" role we created using AWS CDK.
    client = boto3.client("sts")
    return boto3.session.Session()

def download_llama():
    session = assumed_role_session()
    my_bucket = session.resource('s3').Bucket(BUCKET_NAME)
    if not(os.path.exists('llama')):
        os.mkdir('llama')

    # download file into current directory
    for s3_object in my_bucket.objects.filter(Prefix='llama/').all():
        # Need to split s3_object.key into path and file name, else it will give error file not found.
        path, filename = os.path.split(s3_object.key)
        if filename:
            my_bucket.download_file(s3_object.key, f"llama/{filename}")

# %%
download_llama()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 download_llama()
#
# Cell In[11], line 19, in download_llama()
#      17 path, filename = os.path.split(s3_object.key)
#      18 if filename:
# ---> 19     my_bucket.download_file(s3_object.key, f"llama/{filename}")
#
# File /opt/conda/lib/python3.10/site-packages/boto3/s3/inject.py:279, in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     245 def bucket_download_file(
#     246     self, Key, Filename, ExtraArgs=None, Callback=None, Config=None
#     247 ):
#     248     """Download an S3 object to a file.
#     249
#     250     Usage::
#    (...)
#     277         transfer.
#     278     """
# --> 279     return self.meta.client.download_file(
#     280         Bucket=self.name,
#     281         Key=Key,
#     282         Filename=Filename,
#     283         ExtraArgs=ExtraArgs,
#     284         Callback=Callback,
#     285         Config=Config,
#     286     )
#
# File /opt/conda/lib/python3.10/site-packages/boto3/s3/inject.py:192, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     157 """Download an S3 object to a file.
#     158
#     159 Usage::
#    (...)
#     189     transfer.
#     190 """
#     191 with S3Transfer(self, Config) as transfer:
# --> 192     return transfer.download_file(
#     193         bucket=Bucket,
#     194         key=Key,
#     195         filename=Filename,
#     196         extra_args=ExtraArgs,
#     197         callback=Callback,
#     198     )
#
# File /opt/conda/lib/python3.10/site-packages/boto3/s3/transfer.py:405, in S3Transfer.download_file(self, bucket, key, filename, extra_args, callback)
#     401 future = self._manager.download(
#     402     bucket, key, filename, extra_args, subscribers
#     403 )
#     404 try:
# --> 405     future.result()
#     406 # This is for backwards compatibility where when retries are
#     407 # exceeded we need to throw the same error from boto3 instead of
#     408 # s3transfer's built in RetriesExceededError as current users are
#     409 # catching the boto3 one instead of the s3transfer exception to do
#     410 # their own retries.
#     411 except S3TransferRetriesExceededError as e:
#
# File /opt/conda/lib/python3.10/site-packages/s3transfer/futures.py:106, in TransferFuture.result(self)
#     104 except KeyboardInterrupt as e:
#     105     self.cancel()
# --> 106     raise e
#
# File /opt/conda/lib/python3.10/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File /opt/conda/lib/python3.10/site-packages/s3transfer/futures.py:261, in TransferCoordinator.result(self)
#     251 """Waits until TransferFuture is done and returns the result
#     252
#     253 If the TransferFuture succeeded, it will return the result. If the
#     254 TransferFuture failed, it will raise the exception associated to the
#     255 failure.
#     256 """
#     257 # Doing a wait() with no timeout cannot be interrupted in python2 but
#     258 # can be interrupted in python3 so we just wait with the largest
#     259 # possible value integer value, which is on the scale of billions of
#     260 # years...
# --> 261 self._done_event.wait(MAXINT)
#     263 # Once done waiting, raise an exception if present or return the
#     264 # final result.
#     265 if self._exception:
#
# File /opt/conda/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /opt/conda/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    LlamaForCausalLM,
)

model = LlamaForCausalLM.from_pretrained(
    "llama",
)

tokenizer = AutoTokenizer.from_pretrained(
    "llama",
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       1 import torch
#       2 from transformers import (
#       3     AutoModelForCausalLM,
#       4     AutoTokenizer,
#       5     BitsAndBytesConfig,
#       6     LlamaForCausalLM,
#       7 )
# ----> 9 model = LlamaForCausalLM.from_pretrained(
#      10     "llama",
#      11 )
#      13 tokenizer = AutoTokenizer.from_pretrained(
#      14     "llama",
#      15 )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:3754, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3744     if dtype_orig is not None:
#    3745         torch.set_default_dtype(dtype_orig)
#    3747     (
#    3748         model,
#    3749         missing_keys,
#    3750         unexpected_keys,
#    3751         mismatched_keys,
#    3752         offload_index,
#    3753         error_msgs,
# -> 3754     ) = cls._load_pretrained_model(
#    3755         model,
#    3756         state_dict,
#    3757         loaded_state_dict_keys,  # XXX: rename?
#    3758         resolved_archive_file,
#    3759         pretrained_model_name_or_path,
#    3760         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3761         sharded_metadata=sharded_metadata,
#    3762         _fast_init=_fast_init,
#    3763         low_cpu_mem_usage=low_cpu_mem_usage,
#    3764         device_map=device_map,
#    3765         offload_folder=offload_folder,
#    3766         offload_state_dict=offload_state_dict,
#    3767         dtype=torch_dtype,
#    3768         hf_quantizer=hf_quantizer,
#    3769         keep_in_fp32_modules=keep_in_fp32_modules,
#    3770         gguf_path=gguf_path,
#    3771     )
#    3773 # make sure token embedding weights are still tied if needed
#    3774 model.tie_weights()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:4233, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4231         error_msgs += new_error_msgs
#    4232 else:
# -> 4233     error_msgs += _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#    4235 # force memory release
#    4236 del state_dict
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:703, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#     700         if child is not None:
#     701             load(child, state_dict, prefix + name + ".")
# --> 703 load(model_to_load, state_dict, prefix=start_prefix)
#     704 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     705 # it's safe to delete it.
#     706 del state_dict
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:701, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     699 for name, child in module._modules.items():
#     700     if child is not None:
# --> 701         load(child, state_dict, prefix + name + ".")
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:701, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     699 for name, child in module._modules.items():
#     700     if child is not None:
# --> 701         load(child, state_dict, prefix + name + ".")
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 701 (2 times)]
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:701, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     699 for name, child in module._modules.items():
#     700     if child is not None:
# --> 701         load(child, state_dict, prefix + name + ".")
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:697, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     695                     module._load_from_state_dict(*args)
#     696     else:
# --> 697         module._load_from_state_dict(*args)
#     699 for name, child in module._modules.items():
#     700     if child is not None:
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1942, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    1940 try:
#    1941     with torch.no_grad():
# -> 1942         param.copy_(input_param)
#    1943 except Exception as ex:
#    1944     error_msgs.append('While copying the parameter named "{}", '
#    1945                       'whose dimensions in the model are {} and '
#    1946                       'whose dimensions in the checkpoint are {}, '
#    1947                       'an exception occurred : {}.'
#    1948                       .format(key, param.size(), input_param.size(), ex.args))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Quantization:
#
# Quantization is about reducing computational and memory costs by representing weights and activations with low-precision data types. For example, instead of 32-bit floating point, we can use 8-bit integers. This reduces memory usage, energy consumption, and speeds up operations like matrix multiplication.
#
# Quantization Techniques: Two common quantization cases are float32 to float16 and float32 to int8. The former is straightforward, while the latter involves projecting the float32 range to the int8 space using quantization parameters like scale and zero-point.
#
#
# ![quant ft](images/quant-ft.png)
#
#
# ![quant perf](images/quant-perf.png)

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    LlamaForCausalLM,
)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model = LlamaForCausalLM.from_pretrained(
    "llama",
    quantization_config=bnb_config,
)

tokenizer = AutoTokenizer.from_pretrained(
    "llama",
    quantization_config=bnb_config,
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 16
#       2 from transformers import (
#       3     AutoModelForCausalLM,
#       4     AutoTokenizer,
#       5     BitsAndBytesConfig,
#       6     LlamaForCausalLM,
#       7 )
#       9 bnb_config = BitsAndBytesConfig(
#      10     load_in_4bit=True,
#      11     bnb_4bit_use_double_quant=False,
#      12     bnb_4bit_quant_type="nf4",
#      13     bnb_4bit_compute_dtype=torch.bfloat16,
#      14 )
# ---> 16 model = LlamaForCausalLM.from_pretrained(
#      17     "llama",
#      18     quantization_config=bnb_config,
#      19 )
#      21 tokenizer = AutoTokenizer.from_pretrained(
#      22     "llama",
#      23     quantization_config=bnb_config,
#      24 )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:3202, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3199     hf_quantizer = None
#    3201 if hf_quantizer is not None:
# -> 3202     hf_quantizer.validate_environment(
#    3203         torch_dtype=torch_dtype, from_tf=from_tf, from_flax=from_flax, device_map=device_map
#    3204     )
#    3205     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    3206     device_map = hf_quantizer.update_device_map(device_map)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:62, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      60 def validate_environment(self, *args, **kwargs):
#      61     if not torch.cuda.is_available():
# ---> 62         raise RuntimeError("No GPU found. A GPU is needed for quantization.")
#      63     if not (is_accelerate_available() and is_bitsandbytes_available()):
#      64         raise ImportError(
#      65             "Using `bitsandbytes` 8-bit quantization requires Accelerate: `pip install accelerate` "
#      66             "and the latest version of bitsandbytes: `pip install -i https://pypi.org/simple/ bitsandbytes`"
#      67         )
#
# RuntimeError: No GPU found. A GPU is needed for quantization.

# %%
prompt = """Today's date is May 30, 2024. you are given a string with information of an event with time and location. you should extract the information from the given text in json format as shown:
{{"datetime": "yyyy-mm-dd", "location": "str"}} 

here's the text: {text}
json:
"""

# %%
data_file = "examples.txt"
examples = []
# Sample data
with open(data_file, 'r') as file:
    for line in file:
        if line:
            examples.append(line.strip())

# %%
for example in examples:
    inputs = tokenizer(prompt.format(text=example), return_tensors="pt", return_attention_mask=False)
    outputs = model.generate(**inputs, max_length=150)
    text = tokenizer.batch_decode(outputs)[0]
    print(example)
    response = text.split("json:")[-1]
    print(response[:response.find("}") +1])
    print("=======")
# Out:
# On January 15, 2023, display the flooding events in Jakarta.
#
# {"datetime": "2023-01-15", "location": "Jakarta"}
# =======
# Show images of burn scars in the Colorado Rockies from March 12, 2023.
#
# {
#     "datetime": "2023-03-12",
#     "location": "Colorado Rockies"
# }
# =======
# Crop types in Sudan as observed on May 20, 2023.
#
# {
#     "datetime": "2023-05-20",
#     "location": "Sudan"
# }
# =======
# February 8, 2023: Provide satellite imagery of flooding in Miami.
#
# {
# "datetime": "2023-02-08",
# "location": "Miami"
# }
# =======
# Burn scars in Oregon, noted on April 17, 2023.
#
#
# {
#     "datetime": "2023-04-17",
#     "location": "Oregon"
# }
# =======
# July 25, 2023: Identify crop types in Northern India.
#
# {
#     "datetime": "2023-07-25T00:00:00",
#     "location": "Northern India"
# }
# =======
# Flooding in central China on June 30, 2023.
#
# {
#     "datetime": "2023-06-30",
#     "location": "Shanghai"
# }
# =======
# Satellite images of burn scars in Montana from August 14, 2023.
#
# {
#   "datetime": "2023-08-14",
#   "location": "Montana"
# }
# =======
# December 5, 2023: Show crop types in Chile.
#
#
# {"datetime": "2023-12-05", "location": "Chile"}
# =======
# March 22, 2023, highlight flooding events in southern France.
#
# {
#   "datetime": "2023-03-22",
#   "location": "southern France"
# }
# =======
# On November 10, 2023, find burn scars in Victoria, Australia.
#
# {"datetime": "2023-11-10", "location": "Victoria, Australia"}
# =======
# Crop types in Ukraine, recorded on September 3, 2023.
#
# {"datetime": "2023-09-03", "location": "Ukraine"}
# =======
# October 27, 2023: Flooding in Cairo, Egypt.
#
# {
#   "datetime": "2023-10-27",
#   "location": "Cairo, Egypt"
# }
# =======
# January 9, 2023: Display burn scars in the Scottish Highlands.
#
# {
#   "datetime": "2023-01-09",
#   "location": "Scottish Highlands"
# }
# =======
# Crop types in Kansas as of February 16, 2023.
#
# {
#   "datetime": "2023-02-16",
#   "location": "Kansas"
# }
# =======
# Flooding in Bangladesh on March 5, 2023.
#
#
# {
#   "datetime": "2023-03-05",
#   "location": "Bangladesh"
# }
# =======
# April 28, 2023, show burn scars in New Mexico.
#
# {"datetime": "2023-04-28", "location": "New Mexico"}
# =======
# May 15, 2023: Crop types in Brazil.
#
# {
#   "datetime": "2023-05-15",
#   "location": "Brazil"
# }
# =======
# June 11, 2023: Flooding in Houston, Texas.
#
# {
#     "datetime": "2023-06-11",
#     "location": "Houston, Texas"
# }
# =======
# September 7, 2023, display burn scars in Arizona.
#
# {
#   "datetime": "2023-09-07",
#   "location": "Arizona"
# }
# =======
# Crop types in Egypt observed on November 2, 2023.
#
# {
#   "datetime": "2023-11-02",
#   "location": "Egypt"
# }
# =======
# December 18, 2023: Flooding in Venice.
#
# {
#   "datetime": "2023-12-18",
#   "location": "Venice"
# }
# =======
# January 22, 2023: Burn scars in British Columbia.
#
# {
#   "datetime": "2023-01-22",
#   "location": "British Columbia"
# }
# =======
# March 19, 2023: Crop types in Ethiopia.
#
#
# {"datetime": "2023-03-19", "location": "Ethiopia"}
# =======
# July 14, 2023, flooding in Seoul.
#
#
# {
#   "datetime": "2023-07-14",
#   "location": "Seoul"
# }
# =======
# Burn scars in the Amazon rainforest on August 26, 2023.
#
#
# {
#     "datetime": "2023-08-26",
#     "location": "Burn scars in the Amazon rainforest"
# }
# =======
# October 13, 2023, show crop types in Italy.
#
# {
# "datetime": "2023-10-13",
# "location": "Italy"
# }
# =======
# Flooding in the Netherlands on February 21, 2023.
#
# {
#     "datetime": "2023-02-21",
#     "location": "Netherlands"
# }
# =======
# On April 4, 2023, display burn scars in California.
#
# {
#     "datetime": "2023-04-04",
#     "location": "California"
# }
# =======
# Crop types in Morocco as of May 28, 2023.
#
# {
#   "datetime": "2023-05-28",
#   "location": "Morocco"
# }
# =======
# Flooding in São Paulo on June 19, 2023.
#
# {
#     "datetime": "2023-06-19",
#     "location": "São Paulo"
# }
# =======
# Satellite imagery of burn scars in Utah from September 9, 2023.
#
# {
#   "datetime": "2023-09-09",
#   "location": "Utah"
# }
# =======
# November 23, 2023: Crop types in Vietnam.
#
# {
#     "datetime": "2023-11-23",
#     "location": "Vietnam"
# }
# =======
# December 3, 2023, highlight flooding events in Manila.
#
#
# {
#   "datetime": "2023-12-03T10:00:00.000Z",
#   "location": "Manila"
# }
# =======
# January 31, 2023: Burn scars in Nevada.
#
# {
#   "datetime": "2023-01-31T00:00:00.000Z",
#   "location": "Nevada"
# }
# =======
# Crop types in Poland, noted on March 24, 2023.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Warsaw, Poland"
# }
# =======
# Flooding in Malaysia on July 8, 2023.
#
# {"datetime": "2023-07-08", "location": "Malaysia"}
# =======
# Satellite images of burn scars from Siberia on August 17, 2023.
#
# {
#     "datetime": "2023-08-17",
#     "location": "Siberia"
# }
# =======
# Crop types in Turkey as of October 6, 2023.
#
# {
#   "datetime": "2023-10-06",
#   "location": "Ankara, Turkey"
# }
# =======
# November 27, 2023: Flooding in London.
#
# {
#     "datetime": "2023-11-27",
#     "location": "London"
# }
# =======
# January 16, 2023, show burn scars in Tasmania.
#
# {
#   "datetime": "2023-01-16",
#   "location": "Tasmania"
# }
# =======
# Crop types in Greece observed on February 25, 2023.
#
# {
#   "datetime": "2023-02-25",
#   "location": "Greece"
# }
# =======
# On March 10, 2023, find flooding events in New Orleans.
#
# {
#   "datetime": "2023-03-10",
#   "location": "New Orleans"
# }
# =======
# April 20, 2023: Burn scars in Portugal.
#
# {
#   "datetime": "2023-04-20",
#   "location": "Portugal"
# }
# =======
# Crop types in South Africa from May 22, 2023.
#
# {
#     "datetime": "2023-05-22",
#     "location": "South Africa"
# }
# =======
# Flooding in the Philippines on June 28, 2023.
#
# {
#     "datetime": "2023-06-28",
#     "location": "Manila"
# }
# =======
# July 12, 2023, display burn scars in South Dakota.
#
# {
#     "datetime": "2023-07-12",
#     "location": "South Dakota"
# }
# =======
# Crop types in Argentina as of September 15, 2023.
#
# {
#     "datetime": "2024-05-30T00:00:00.000Z",
#     "location": "New York, NY"
# }
# =======
# October 31, 2023: Flooding in Berlin.
#
# {
#     "datetime": "2023-10-31",
#     "location": "Berlin"
# }
# =======
# Satellite imagery of burn scars in New Zealand from December 9, 2023.
#
# {
#   "datetime": "2023-12-09",
#   "location": "New Zealand"
# }
# =======
# January 4, 2023: Crop types in Japan.
#
# {
#     "datetime": "2023-01-04",
#     "location": "Japan"
# }
# =======
# March 6, 2023, show flooding in Alabama.
#
#
# {
#   "datetime": "2023-03-06",
#   "location": "Alabama"
# }
# =======
# April 29, 2023: Burn scars in the Sahel region.
#
#
# {
#   "datetime": "2023-04-29",
#   "location": "Burn scars in the Sahel region."
# }
# =======
# Crop types in Belgium noted on May 24, 2023.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Belgium"
# }
# =======
# Flooding in South Korea on June 15, 2023.
#
# {
#     "datetime": "2023-06-15",
#     "location": "South Korea"
# }
# =======
# Burn scars in Alaska from July 21, 2023.
#
# {
#   "datetime": "2023-07-21",
#   "location": "Alaska"
# }
# =======
# Crop types in Romania as of August 30, 2023.
#
# =======
# September 20, 2023: Flooding in Lima, Peru.
#
#
# {
#   "datetime": "2023-09-20",
#   "location": "Lima, Peru"
# }
# =======
# November 5, 2023, display burn scars in the Pyrenees.
#
# {
#     "datetime": "2023-11-05",
#     "location": "Pyrenees"
# }
# =======
# On January 15, 2023, display the flooding events in Jakarta.
#
#
# {
#     "datetime": "2023-01-15",
#     "location": "Jakarta"
# }
# =======
# Show images of burn scars in the Colorado Rockies from March 12, 2023.
#
# {
#     "datetime": "2023-03-12T00:00:00Z",
#     "location": "Colorado Rockies"
# }
# =======
# Crop types in Sudan as observed on May 20, 2023.
#
# {
#     "datetime": "2023-05-20",
#     "location": "Sudan"
# }
# =======
# February 8, 2023: Provide satellite imagery of flooding in Miami.
#
# =======
# Burn scars in Oregon, noted on April 17, 2023.
#
# {
#   "datetime": "2023-04-17",
#   "location": "Oregon"
# }
# =======
# July 25, 2023: Identify crop types in Northern India.
#
# {
#     "datetime": "2023-07-25",
#     "location": "Northern India"
# }
# =======
# Flooding in central China on June 30, 2023.
#
# {
#     "datetime": "2023-06-30",
#     "location": "Hubei"
# }
# =======
# Satellite images of burn scars in Montana from August 14, 2023.
#
# {"datetime": "2023-08-14", "location": "Montana"}
# =======
# December 5, 2023: Show crop types in Chile.
#
# {
# "datetime": "2023-12-05",
# "location": "Chile"
# }
# =======
# March 22, 2023, highlight flooding events in southern France.
#
# {
#     "datetime": "2023-03-22",
#     "location": "southern France"
# }
# =======
# On November 10, 2023, find burn scars in Victoria, Australia.
#
# {
# "datetime": "2023-11-10",
# "location": "Victoria, Australia"
# }
# =======
# Crop types in Ukraine, recorded on September 3, 2023.
#
#
# {
#     "datetime": "2023-09-03T00:00:00",
#     "location": "Ukraine"
# }
# =======
# October 27, 2023: Flooding in Cairo, Egypt.
#
# {
#   "datetime": "2023-10-27",
#   "location": "Cairo, Egypt"
# }
# =======
# January 9, 2023: Display burn scars in the Scottish Highlands.
#
#
# {"datetime": "2023-01-09", "location": "Scottish Highlands"}
# =======
# Crop types in Kansas as of February 16, 2023.
#
# {
#     "datetime": "2023-02-16",
#     "location": "Kansas"
# }
# =======
# Flooding in Bangladesh on March 5, 2023.
#
# {
#     "datetime": "2023-03-05",
#     "location": "Bangladesh"
# }
# =======
# April 28, 2023, show burn scars in New Mexico.
#
# =======
# May 15, 2023: Crop types in Brazil.
#
# {
#   "datetime": "2023-05-15",
#   "location": "Brazil"
# }
# =======
# June 11, 2023: Flooding in Houston, Texas.
#
# {
#     "datetime": "2023-06-11",
#     "location": "Houston, Texas"
# }
# =======
# September 7, 2023, display burn scars in Arizona
#
# {
#     "datetime": "2023-09-07",
#     "location": "Arizona"
# }
# =======
# Provide the latest imagery of flooding in Houston, Texas, from this past Tuesday.
#
# {
#     "datetime": "2024-05-28",
#     "location": "Houston, Texas"
# }
# =======
# Display satellite images of burn scars in the Alps as of June 2024.
#
# {
#   "datetime": "2024-06-01",
#   "location": "Burn scars in the Alps"
# }
# =======
# Can you show crop types in Vietnam observed last Friday?
#
# {
#     "datetime": "2024-05-30",
#     "location": "Hanoi"
# }
# =======
# Highlight recent flooding events in the UK from this past Spring.
#
# =======
# Show images of burn scars in Utah as of the first week of May 2024.
#
# =======
# Find current crop types in Poland as observed today.
#
# {
#     "datetime": "2024-05-30T00:00:00.0000000+00:00",
#     "location": "Warsaw"
# }
# =======
# Display the latest flooding events in Toronto, Canada, from last month.
#
# =======
# Show satellite imagery of burn scars in Morocco from this year.
#
#
# {"datetime": "2024-05-30", "location": "Marrakesh"}
# =======
# Can you find crop types in Kansas as of the last 30 days?
#
# {
#   "datetime": "2021-09-28",
#   "location": "Kansas"
# }
# =======
# Provide images of recent flooding in Cairo, Egypt, from the past week.
#
# {
# "datetime": "2024-05-30",
# "location": "Cairo, Egypt"
# }
# =======
# Highlight burn scars in Tasmania as observed last Monday.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Tasmania"
# }
# =======
# Display the most recent crop types in Germany from this Wednesday.
#
# =======
# Show recent flooding in Miami, Florida, as of this April.
#
# =======
# Find burn scars in the Kalahari Desert from the past three months.
#
# {
#     "datetime": "2021-05-30",
#     "location": "South Africa"
# }
# =======
# Can you show crop types in the Netherlands observed last weekend?
#
# {
#     "datetime": "2024-05-30",
#     "location": "Groningen"
# }
# =======
# Highlight flooding events in Lima, Peru, from this Spring.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Lima, Peru"
# }
# =======
# Display current burn scars in South Dakota as of today.
#
# =======
# Show the most recent crop types in Turkey from last Tuesday.
#
# {
#   "datetime": "2024-05-30",
#   "location": "Istanbul"
# }
# =======
# Provide satellite images of flooding in Seoul, South Korea, from this month.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Seoul, South Korea"
# }
# =======
# Find burn scars in the Andes Mountains from last season.
#
# {
# "datetime": "2024-05-30",
# "location": "Chile"
# }
# =======
# Display the latest crop types in Israel observed this Friday.
#
#
# {"datetime": "2024-05-30", "location": "Israel"}
# =======
# Show recent flooding events in Sao Paulo, Brazil, from two weeks ago.
#
# {
#   "datetime": "2022-05-16",
#   "location": "Sao Paulo, Brazil"
# }
# =======
# Highlight burn scars in Montana from May 2024.
#
# {
#   "datetime": "2024-05-03",
#   "location": "Montana"
# }
# =======
# Can you show crop types in Bulgaria as of this morning?
#
# =======
# Display recent flooding in New York City from the last 48 hours.
#
# {
#   "datetime": "2022-05-28",
#   "location": "Brooklyn"
# }
# =======
# Find the most recent burn scars in Fiji from the past year.
#
#
# {
#   "datetime": "2024-05-30",
#   "location": "Fiji"
# }
# =======
# Show the current crop types in Cuba as of this quarter.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Cuba"
# }
# =======
# Highlight flooding events in Paris, France, from last weekend.
#
# {
#     "datetime": "2022-05-28",
#     "location": "Paris, France"
# }
# =======
# Display satellite imagery of burn scars in Tasmania from this summer.
#
# {
#   "datetime": "2024-05-30T00:00:00Z",
#   "location": "Hobart, Australia"
# }
# =======
# Can you find crop types in Egypt observed last Thursday?
#
#
# {
#     "datetime": "2024-05-30",
#     "location": "Egypt"
# }
# =======
# Show recent flooding in Beijing, China, from the first week of June 2024.
#
# {
#     "datetime": "2024-06-01",
#     "location": "Beijing, China"
# }
# =======
# Display burn scars in Nova Scotia from last month.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Nova Scotia"
# }
# =======
# Highlight crop types in Argentina seen this past weekend.
#
#
# {
#   "datetime": "2024-05-30",
#   "location": "Buenos Aires"
# }
# =======
# Find recent flooding events in Dubai from today.
#
#
# {"datetime": "2022-05-24", "location": "Dubai"}
# =======
# Show the most recent burn scars in the Pyrenees from this week.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Pyrenees"
# }
# =======
# Display crop types in South Korea observed yesterday.
#
#
# {"datetime": "2024-05-30", "location": "Gyeonggi-do"}
# =======
# Provide images of flooding in Lagos, Nigeria, from the last 72 hours.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Lagos, Nigeria"
# }
# =======
# Show burn scars in the Everglades from last season.
#
# {
#   "datetime": "2024-05-30",
#   "location": "Everglades"
# }
# =======
# Highlight crop types in Sweden as of the end of May 2024.
#
# {"datetime": "2024-05-30", "location": "Sweden"}
# =======
# Find recent flooding in Venice, Italy, from last Saturday.
#
# {
#     "datetime": "2024-05-30",
#     "location": "Venice, Italy"
# }
# =======
# Display the latest burn scars in the Sierra Nevada from this month.
#
# =======
# Show current crop types in Greece as observed this Monday.
#
#
# {
#     "datetime": "2024-05-30",
#     "location": "Athens"
# }
# =======
# Provide satellite images of flooding in Kyoto, Japan, from this year.
#
# {
#   "datetime": "2024-05-30",
#   "location": "Kyoto, Japan"
# }
# =======
# Find the most recent burn scars in the Rocky Mountains from last Tuesday.
#
# {
#     "datetime": "2024-05-28",
#     "location": "Rocky Mountains"
# }
# =======
# Display crop types in Morocco as of today.
#
# {"datetime": "2024-05-30", "location": "Morocco"}
# =======
# Highlight recent flooding events in Bangkok, Thailand, from the past week.
#
# {"datetime": "2024-05-30", "location": "Bangkok"}
# =======
# Show burn scars in the Amazon from this Spring.
#
# {
#   "datetime": "2024-05-30T00:00:00.000Z",
#   "location": "52.466724, -17.115113"
# }
# =======

# %%
# !nvidia-smi

# %%
prompt.format(text=example)

# %%
example
